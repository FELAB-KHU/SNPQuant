# %%
import pandas as pd
import numpy as np
import os

import seaborn as sns
import matplotlib as mpl
from matplotlib import pyplot as plt

# %matplotlib inline
pd.options.display.max_columns = 100

# font check
from matplotlib import font_manager as fm
for font in fm.fontManager.ttflist:
    if 'Pretendard' in font.name:
        print(font.name, font.fname)

# fe = fm.FontEntry(
#     fname=r'C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard.ttf', # ttf 파일이 저장되어 있는 경로
#     name='Pretendard')                       
# fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
# plt.rcParams.update({'font.size': 10, 'font.family': 'Pretendard'})

plt.rcParams['font.family'] = 'Pretendard'
# Out:
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-SemiBold.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-Bold.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-Regular.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-Black.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-Medium.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-ExtraLight.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-Light.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-ExtraBold.ttf
# Pretendard C:\Users\FELAB\AppData\Local\Microsoft\Windows\Fonts\Pretendard-Thin.ttf

# %%
exchanges = pd.read_csv('exchanges_cap.csv')
exchanges
# Out:
#     exchange_id    symbol goog_symbol                                    name  \
# 0            52      NYSE        NYSE                 New York Stock Exchange
# 1            45    NASDAQ      NASDAQ                   NASDAQ Stock Exchange
# 2            46  NASDAQCM      NASDAQ                   Nasdaq Capital Market
# 3            47  NASDAQGM      NASDAQ                    Nasdaq Global Market
# 4            48  NASDAQGS      NASDAQ                    Nasdaq Global Select
# 5            75       SSE         SHA                 Shanghai Stock Exchange
# 6            66       PSI         ELI                    NYSE Euronext Lisbon
# 7             1       AEX         AMS                 NYSE Euronext Amsterdam
# 8            64       PAR         EPA                     NYSE Euronext Paris
# 9             8       BEL         EBR                  NYSE Euronext Brussels
# 10           82       TSE         TYO                    Tokyo Stock Exchange
# 11           77      SZSE         SHE                 Shenzhen Stock Exchange
# 12           28      HKEX         HKG                Hong Kong Stock Exchange
# 13           49       NSE         NSE        National Stock Exchange of India
# 14           36       LSE         LON                   London Stock Exchange
# 15           83       TSX         TSE                  Toronto Stock Exchange
# 16           84      TSXV         CVE                    TSX Venture Exchange
# 17           78   TADAWUL     TADAWUL                    Saudi Stock Exchange
# 18           23       FRA         FRA  Deutsche B?se Frankfurt Stock Exchange
# 19           90     XETRA         ETR                    Deutsche Borse XETRA
# 20           74       SIX         SWX                      SIX Swiss Exchange
# 21           87       VTX         VTX                      SIX Swiss Exchange
# 22           86       VSE         VSE                      NASDAQ OMX Vilnius
# 23           29      ICEX         ICE                      NASDAQ OMX Iceland
# 24           80       TAL         TAL                      NASDAQ OMX Tallinn
# 25           19       CSE         CPH                   NASDAQ OMX Copenhagen
# 26           34       KSC         KRX                    Korea Stock Exchange
# 27           35      KSCQ      KOSDAQ                                  KOSDAQ
# 28           79     TAIEX         TPE                   Taiwan Stock Exchange
# 29           85       TWO         NaN                     Taiwan OTC Exchange
# 30            5       ASX         ASX               Australian Stock Exchange
# 31           33       JSE         JSE             Johannesburg Stock Exchange
#
#            country           city currency time_zone  시가총액
# 0    United States  New York City      USD       EST     1
# 1    United States  New York City      USD       EST     2
# 2    United States  New York City      USD       EST     2
# 3    United States  New York City      USD       EST     2
# 4    United States  New York City      USD       EST     2
# 5            China       Shanghai      CNY       CST     3
# 6         Portugal         Lisbon      EUR       CET     4
# 7      Netherlands      Amsterdam      EUR       CET     4
# 8           France          Paris      EUR       CET     4
# 9          Belgium       Brussels      EUR       CET     4
# 10           Japan          Tokyo      JPY       JST     5
# 11           China       Shenzhen      CNY       CST     6
# 12       Hong Kong      Hong Kong      HKD       HKT     7
# 13           India         Mumbai      INR       IST     8
# 14  United Kingdom         London      GBP       GMT     9
# 15          Canada        Toronto      CAD       EST    10
# 16          Canada        Toronto      CAD       EST    10
# 17    Saudi Arabia         Riyadh      SAR       NaN    11
# 18         Germany      Frankfurt      EUR       CET    12
# 19         Germany      Frankfurt      EUR       CET    12
# 20     Switzerland         Zurich      CHF       CET    13
# 21     Switzerland         Zurich      CHF       CET    13
# 22       Lithuania        Vilnius      LTL       EET    14
# 23         Iceland      Rejkjavik      ISK       NaN    14
# 24         Estonia        Tallinn      EUR       EET    14
# 25         Denmark     Copenhagen      DKK       CET    14
# 26     South Korea          Seoul      KRW       KST    15
# 27     South Korea          Seoul      KRW       KST    15
# 28          Taiwan         Taipei      TWD       CST    16
# 29          Taiwan         Taipei      TWD       NaN    16
# 30       Australia         Sydney      AUD      AEST    17
# 31    South Africa   Johannesburg      ZAR      SAST    18
